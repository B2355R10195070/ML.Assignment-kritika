# %% [markdown]
# <a href="https://colab.research.google.com/github/B2355R10195070/ML.Assignment-kritika/blob/main/Copy_of_Logistic_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
np.random.seed(42)

# %%
customer_age = np.random.randint(18, 65, 100)

# %%
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

# %%
purchase_prob = sigmoid((customer_age - 40) / 5)
purchase_decision = np.random.binomial(1, purchase_prob)

# %%
data = pd.DataFrame({
    'Customer_Age': customer_age,
    'Purchase_Decision': purchase_decision
})

# %%
data.to_csv('business_logistic_regression_dataset.csv', index=False)

print("Dataset saved as 'business_logistic_regression_dataset.csv'")
# Out:
# Dataset saved as 'business_logistic_regression_dataset.csv'

# %%
df = pd.read_csv('business_logistic_regression_dataset.csv')
df.head()
# Out:
#    Customer_Age  Purchase_Decision
# 0            56                  1
# 1            46                  1
# 2            32                  0
# 3            60                  1
# 4            25                  0

# %%
plt.scatter(df.Customer_Age, df.Purchase_Decision, marker='*', color='blue')

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(df[['Customer_Age']], df.Purchase_Decision, train_size=0.8, random_state=42)

# %%
X_test
# Out:
#     Customer_Age
# 83            35
# 53            61
# 70            51
# 45            31
# 44            42
# 39            38
# 22            19
# 80            38
# 10            28
# 0             56
# 18            41
# 30            59
# 73            31
# 33            32
# 90            46
# 4             25
# 76            25
# 77            31
# 12            53
# 31            45

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
X_test
# Out:
#     Customer_Age
# 83            35
# 53            61
# 70            51
# 45            31
# 44            42
# 39            38
# 22            19
# 80            38
# 10            28
# 0             56
# 18            41
# 30            59
# 73            31
# 33            32
# 90            46
# 4             25
# 76            25
# 77            31
# 12            53
# 31            45

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test,y_pred)

# %%
accuracy
# Out:
# 0.75

# %%
X_test
# Out:
#     Customer_Age
# 83            35
# 53            61
# 70            51
# 45            31
# 44            42
# 39            38
# 22            19
# 80            38
# 10            28
# 0             56
# 18            41
# 30            59
# 73            31
# 33            32
# 90            46
# 4             25
# 76            25
# 77            31
# 12            53
# 31            45

# %%
from sklearn.metrics import confusion_matrix

# %%
cm = confusion_matrix(y_test,y_pred)

# %%
cm
# Out:
# array([[8, 1],
#        [4, 7]])

# %%
import seaborn as sns

# %%
plt.figure(figsize=(7,5))
sns.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(58.222222222222214, 0.5, 'Truth')

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.89      0.76         9
#            1       0.88      0.64      0.74        11
#
#     accuracy                           0.75        20
#    macro avg       0.77      0.76      0.75        20
# weighted avg       0.78      0.75      0.75        20

# %%
# Get weight (w) and bias (b)
w = model.coef_[0][0]  # Slope
b = model.intercept_[0]  # Intercept

# %%
w
# Out:
# 0.24738275578989433

# %%
b
# Out:
# -10.265394984499684

# %%
# Prediction Function
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

# %%
def predict_probability(age):
    z = w * age + b
    probability = sigmoid(z)
    return probability

# %%
df.sample()
# Out:
#     Customer_Age  Purchase_Decision
# 46            26                  0

# %%
age_to_predict = 40
probability = predict_probability(age_to_predict)

# %%
probability
# Out:
# 0.4085205424364033
